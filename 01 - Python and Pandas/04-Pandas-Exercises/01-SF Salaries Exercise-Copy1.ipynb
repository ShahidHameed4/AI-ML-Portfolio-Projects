# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
sal =pd.read_csv('Salaries.csv')
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
aray=sal['JobTitle'].unique()
df=sal
aray2=df[['EmployeeName', 'BasePay']] = df[['EmployeeName', 'BasePay']].where(df['TotalPay'] > 
567590.3, df[['BasePay', 'EmployeeName']].values)
aray2
# Out:
#              EmployeeName    BasePay
# 0          NATHANIEL FORD  167411.18
# 1            GARY JIMENEZ  155966.02
# 2          ALBERT PARDINI  212739.13
# 3       CHRISTOPHER CHONG    77916.0
# 4         PATRICK GARDNER   134401.6
# ...                   ...        ...
# 148649      Roy I Tillery        0.0
# 148650       Not provided        NaN
# 148651       Not provided        NaN
# 148652       Not provided        NaN
# 148653          Joe Lopez        0.0
#
# [148654 rows x 2 columns]

# %%
dataframe=pd.read_csv(r'C:\Users\shhdh\Downloads\soc-redditHyperlinks-title.csv')
dataframe
# Out:
#          SOURCE_SUBREDDIT     TARGET_SUBREDDIT  POST_ID         TIMESTAMP  \
# 0              rddtgaming             rddtrust  1u4pzzs  12/31/2013 16:39
# 1                 xboxone        battlefield_4  1u4tmfs  12/31/2013 17:59
# 2                     ps4        battlefield_4  1u4tmos  12/31/2013 17:59
# 3       fitnesscirclejerk            leangains  1u50xfs  12/31/2013 19:01
# 4       fitnesscirclejerk          lifeprotips  1u51nps  12/31/2013 21:02
# ...                   ...                  ...      ...               ...
# 571922    seattleshitshow            seattlewa   68iptp   4/27/2017 11:07
# 571923   peoplewhosayheck            spiderman  68iqh6s   4/30/2017 16:36
# 571924               vzla                  wtf  68iqkcs   4/30/2017 15:50
# 571925      denverbroncos                  nfl   68iqt8   4/30/2017 16:11
# 571926   shitpoliticssays  politicaldiscussion  68ir4os   4/30/2017 15:14
#
#         LINK_SENTIMENT                                         PROPERTIES
# ...

# %%
df=dataframe
aray2=df[['SOURCE_SUBREDDIT', 'TARGET_SUBREDDIT']] = df[['SOURCE_SUBREDDIT', 'TARGET_SUBREDDIT']].where(df['LINK_SENTIMENT'] !=-1, df[['TARGET_SUBREDDIT', 'SOURCE_SUBREDDIT']].values)
df
# Out:
#          SOURCE_SUBREDDIT     TARGET_SUBREDDIT  POST_ID         TIMESTAMP  \
# 0              rddtgaming             rddtrust  1u4pzzs  12/31/2013 16:39
# 1                 xboxone        battlefield_4  1u4tmfs  12/31/2013 17:59
# 2                     ps4        battlefield_4  1u4tmos  12/31/2013 17:59
# 3       fitnesscirclejerk            leangains  1u50xfs  12/31/2013 19:01
# 4       fitnesscirclejerk          lifeprotips  1u51nps  12/31/2013 21:02
# ...                   ...                  ...      ...               ...
# 571922          seattlewa      seattleshitshow   68iptp   4/27/2017 11:07
# 571923   peoplewhosayheck            spiderman  68iqh6s   4/30/2017 16:36
# 571924               vzla                  wtf  68iqkcs   4/30/2017 15:50
# 571925                nfl        denverbroncos   68iqt8   4/30/2017 16:11
# 571926   shitpoliticssays  politicaldiscussion  68ir4os   4/30/2017 15:14
#
#         LINK_SENTIMENT                                         PROPERTIES
# ...

# %% [markdown]
# ** Check the head of the DataFrame. ** saassa

# %%
df['LINK_SENTIMENT']=1
df
# Out:
#          SOURCE_SUBREDDIT     TARGET_SUBREDDIT  POST_ID         TIMESTAMP  \
# 0              rddtgaming             rddtrust  1u4pzzs  12/31/2013 16:39
# 1                 xboxone        battlefield_4  1u4tmfs  12/31/2013 17:59
# 2                     ps4        battlefield_4  1u4tmos  12/31/2013 17:59
# 3       fitnesscirclejerk            leangains  1u50xfs  12/31/2013 19:01
# 4       fitnesscirclejerk          lifeprotips  1u51nps  12/31/2013 21:02
# ...                   ...                  ...      ...               ...
# 571922          seattlewa      seattleshitshow   68iptp   4/27/2017 11:07
# 571923   peoplewhosayheck            spiderman  68iqh6s   4/30/2017 16:36
# 571924               vzla                  wtf  68iqkcs   4/30/2017 15:50
# 571925                nfl        denverbroncos   68iqt8   4/30/2017 16:11
# 571926   shitpoliticssays  politicaldiscussion  68ir4os   4/30/2017 15:14
#
#         LINK_SENTIMENT                                         PROPERTIES
# ...

# %%
df.drop(['TIMESTAMP','LINK_SENTIMENT','PROPERTIES'],axis=1)
# Out:
#          SOURCE_SUBREDDIT     TARGET_SUBREDDIT  POST_ID
# 0              rddtgaming             rddtrust  1u4pzzs
# 1                 xboxone        battlefield_4  1u4tmfs
# 2                     ps4        battlefield_4  1u4tmos
# 3       fitnesscirclejerk            leangains  1u50xfs
# 4       fitnesscirclejerk          lifeprotips  1u51nps
# ...                   ...                  ...      ...
# 571922          seattlewa      seattleshitshow   68iptp
# 571923   peoplewhosayheck            spiderman  68iqh6s
# 571924               vzla                  wtf  68iqkcs
# 571925                nfl        denverbroncos   68iqt8
# 571926   shitpoliticssays  politicaldiscussion  68ir4os
#
# [571927 rows x 3 columns]

# %%
newDataframe=df.head(10000);
array1=newDataframe['SOURCE_SUBREDDIT'].unique()
array1
# Out:
# array(['rddtgaming', 'xboxone', 'ps4', ..., 'tumblr', 'syriancivilwar',
#        'lethbridge'], dtype=object)

# %%
# Out:
# 1
# 1
# 1
# 79

# %%
 x=np.where(array1=='fitnesscirclejerk')
x[0].size==0
if(x[0].size==0):
    array1.append('fitnesscirclejerk')
# Out:
# False

# %%
import string


class Pair:
    def __init__(self, first, second):
        self.first = first
        self.second = second


infi = 100000000000000000000;


# Class of the node
class Node:

    # Adjacency list that shows the
    # vertexNumber of child vertex
    # and the weight of the edge
    def __init__(self, vertexNumber):
        self.vertexNumber = vertexNumber
        self.children = []

    # Function to add the child for
    # the given node
    def Add_child(self, vNumber, length):
        p = Pair(vNumber, length);
        self.children.append(p);

# %%
def BellmanFord(g, s, path):
    # Stores distance of each
    # vertex from source vertex
    dist = [infi for i in range(len(g))]

    # bool array that shows
    # whether the vertex 'i'
    # is visited or not
    visited = [False for i in range(len(g))]

    for i in range(len(g)):
        path[i] = -1
    dist[s] = 0;
    path[s] = -1;
    current = s;

    # Set of vertices that has
    # a parent (one or more)
    # marked as visited
    sett = set()
    path1=[]
    path1.append(current)
    while (True):

        # Mark current as visited
        visited[current] = True;

        for i in range(len(g[current].children)):
            v = g[current].children[i].first;
            path1.append(v);
            if (visited[v]):
                continue;

            # Inserting into the
            # visited vertex
            sett.add(v);
            alt = dist[current] + g[current].children[i].second;





            # Condition to check the distance
            # is correct and update it
            # if it is minimum from the previous
            # computed distance
            if (alt < dist[v]):
                dist[v] = alt;
                path[v] = current;
          #  print(path1);
        if current in sett:
            sett.remove(current);
        if (len(sett) == 0):
            break;

        # The new current
        minDist = infi;
        index = 0;

        # Loop to update the distance
        # of the vertices of the graph
        for a in sett:
            if (dist[a] < minDist):
                minDist = dist[a];
                index = a;
        current = index;
    return dist;


# Function to print the path
# from the source vertex to
# the destination vertex
def printPath(path, i, s,array1):
    if (i != s):

        # Condition to check if
        # there is no path between
        # the vertices
        if (path[i] == -1):
            print("Path not found!!");
            return;
        printPath(path, path[i], s,array1);
        print(str(array1[path[i]])+'-->',end=" ");

# %%
v = []

# %%
loc = np.where(array1=='starcraft')[0]
loc[0]
# Out:
# 1064

# %%
for j in array1:
    z=int(np.where(array1==j)[0][0])
    a = Node(z);
    v.append(a);
    arraycheck=newDataframe[newDataframe['SOURCE_SUBREDDIT']==j]['TARGET_SUBREDDIT']
    for i in arraycheck:
        arraytemp=np.array([i])
        if(np.where(array1==i)[0].size==0):
            array1=np.append(array1,i)
        loc = int(np.where(array1==i)[0][0])
        v[z].Add_child(loc,1)

# %%
array1[1064]
# Out:
# 'starcraft'

# %%
len(v)
# Out:
# 2990

# %%
# Out:
#          SOURCE_SUBREDDIT TARGET_SUBREDDIT  POST_ID        TIMESTAMP  \
# 55        allthingsterran        starcraft  1u5ve3s    1/1/2014 8:23
# 57          allthingszerg        starcraft  1u5wyjs    1/1/2014 8:45
# 649   starcraftcirclejerk        starcraft  1ucf91s   1/3/2014 11:23
# 874               esports        starcraft  1uereos   1/4/2014 16:38
# 909               destiny        starcraft  1uf54gs   1/4/2014 14:40
# 974   starcraftcirclejerk        starcraft  1ug2xts   1/4/2014 21:08
# 2101  starcraftcirclejerk        starcraft  1ur309s   1/8/2014 15:26
# 2707              dedgaem        starcraft  1ux3cks  1/12/2014 23:02
# 2906               bestof        starcraft  1uzahbs  1/11/2014 12:10
# 2948              dedgaem        starcraft  1uzpv4s  1/12/2014 23:02
# 3443     allthingsprotoss        starcraft  1v49yss   1/13/2014 8:58
# 3505              dedgaem        starcraft  1v4rqis  1/13/2014 12:23
# 3513  starcraftcirclejerk        starcraft  1v4txts  1/13/2014 12:23
# ...

# %%
def dijkstraDist(g, s, path):
    # Stores distance of each
    # vertex from source vertex
    dist = [infi for i in range(len(g))]

    # bool array that shows
    # whether the vertex 'i'
    # is visited or not
    visited = [False for i in range(len(g))]

    for i in range(len(g)):
        path[i] = -1
    dist[s] = 0;
    path[s] = -1;
    current = s;

    # Set of vertices that has
    # a parent (one or more)
    # marked as visited
    sett = set()
    path1=[]
    path1.append(current)
    while (True):

        # Mark current as visited
        visited[current] = True;

        for i in range(len(g[current].children)):
            v = g[current].children[i].first;
            path1.append(v);
            if (visited[v]):
                continue;

            # Inserting into the
            # visited vertex
            sett.add(v);
            distTemp=g[current].children[i].second;
            if(distTemp>=0):
                alt = dist[current] + g[current].children[i].second;
            else:
                alt = dist[current]
            # alt = dist[current] + g[current].children[i].second;




            # Condition to check the distance
            # is correct and update it
            # if it is minimum from the previous
            # computed distance
            if (alt < dist[v]):
                dist[v] = alt;
                path[v] = current;
          #  print(path1);
        if current in sett:
            sett.remove(current);
        if (len(sett) == 0):
            break;

        # The new current
        minDist = infi;
        index = 0;

        # Loop to update the distance
        # of the vertices of the graph
        for a in sett:
            if (dist[a] < minDist):
                minDist = dist[a];
                index = a;
        current = index;
    return dist;

# %%
n = array1.size;
s = 8;

path = [0 for i in range(len(v))];
# print(path);
dist = dijkstraDist(v, s, path);

# print(path);
printPath(path, 2991,s,array1);
print(str(array1[2991]),end=" ")
print(" ")

    # Loop to print the distance of
    # every node from source vertex
for i in range(len(dist)):
    if (dist[i] == infi):
       #print("{0} and {1} are not " +"connected".format(i, s))
        continue;
    print("Distance of {}th vertex from source vertex {} is: {}".format(i, s, dist[i]));

# %%
n = array1.size;
s = 8;

path = [0 for i in range(len(v))];
# print(path);
dist = BellmanFord(v, s, path);

# print(path);
printPath(path, 2991,s,array1);
print(str(array1[2991]),end=" ")
print(" ")

    # Loop to print the distance of
    # every node from source vertex
for i in range(len(dist)):
    if (dist[i] == infi):
       #print("{0} and {1} are not " +"connected".format(i, s))
        continue;
    print("Distance of {}th vertex from source vertex {} is: {}".format(i, s, dist[i]));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 6>()
#       4 path = [0 for i in range(len(v))];
#       5 # print(path);
# ----> 6 dist = Bellmanford(v, s, path);
#       8 # print(path);
#       9 printPath(path, 2991,s,array1);
#
# NameError: name 'Bellmanford' is not defined

# %%
maxd=-1;
for j in array1:
    s=z=int(np.where(array1==j)[0][0])
    path = [0 for i in range(len(v))];
# print(path);
    dist = dijkstraDist(v, s, path);
    for i in dist:
        if(i!=100000000000000000000):
            if(i>maxd):
                maxd=i
        
# for i in dist:
#     if(i!=100000000000000000000):
#         if(i>maxd):
#             maxd=i
#             print(i)

# print(dist[82])


print("Diameter of graph: " + str(maxd));
# Out:
# Path not found!!
# garrysmod
# Distance of 1th vertex from source vertex 8 is: 2
# Distance of 2th vertex from source vertex 8 is: 2
# Distance of 3th vertex from source vertex 8 is: 2
# Distance of 6th vertex from source vertex 8 is: 2
# Distance of 7th vertex from source vertex 8 is: 2
# Distance of 8th vertex from source vertex 8 is: 0
# Distance of 12th vertex from source vertex 8 is: 2
# Distance of 14th vertex from source vertex 8 is: 1
# Distance of 17th vertex from source vertex 8 is: 1
# Distance of 18th vertex from source vertex 8 is: 1
# Distance of 19th vertex from source vertex 8 is: 1
# Distance of 20th vertex from source vertex 8 is: 2
# Distance of 21th vertex from source vertex 8 is: 2
# Distance of 22th vertex from source vertex 8 is: 2
# Distance of 23th vertex from source vertex 8 is: 1
# Distance of 24th vertex from source vertex 8 is: 3
# Distance of 25th vertex from source vertex 8 is: 2
# Distance of 28th vertex from source vertex 8 is: 4
# ...

# %%
sal.head()

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']

#['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ** How many unique job titles are there? **

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
#sal[sal['JobTitle'].str.contains('Chief')]
def jobChief(x):
    if 'chief' in x.lower():
        return True
    else:
        return False
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
#sum(sal['JobTitle'].apply(lambda x: chief_string(x)))
sum(sal['JobTitle'].apply(lambda x: jobChief(x)))
# Out:
# 627

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %% [markdown]
# # Great Job!

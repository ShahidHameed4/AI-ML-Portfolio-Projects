# %% [markdown]
# # Algo Project
#
# Implemetation of Dijikstra and Bellman Ford including diameter of the whole graph using Pandas Library of Python! We will be using the [SOC reddit Hyper Links dataset] from Snap!
# Completed by Shahid Hameed Chaudhary 20i-0980

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ** Read soc-redditHyperlinks-title.csv as a dataframe called dataframe.**

# %%
dataframe=pd.read_csv(r'C:\Users\shhdh\Downloads\soc-redditHyperlinks-title.csv')
dataframe
# Out:
#          SOURCE_SUBREDDIT     TARGET_SUBREDDIT  POST_ID         TIMESTAMP  \
# 0              rddtgaming             rddtrust  1u4pzzs  12/31/2013 16:39
# 1                 xboxone        battlefield_4  1u4tmfs  12/31/2013 17:59
# 2                     ps4        battlefield_4  1u4tmos  12/31/2013 17:59
# 3       fitnesscirclejerk            leangains  1u50xfs  12/31/2013 19:01
# 4       fitnesscirclejerk          lifeprotips  1u51nps  12/31/2013 21:02
# ...                   ...                  ...      ...               ...
# 571922    seattleshitshow            seattlewa   68iptp   4/27/2017 11:07
# 571923   peoplewhosayheck            spiderman  68iqh6s   4/30/2017 16:36
# 571924               vzla                  wtf  68iqkcs   4/30/2017 15:50
# 571925      denverbroncos                  nfl   68iqt8   4/30/2017 16:11
# 571926   shitpoliticssays  politicaldiscussion  68ir4os   4/30/2017 15:14
#
#         LINK_SENTIMENT                                         PROPERTIES
# 0                    1  25.0,23.0,0.76,0.0,0.44,0.12,0.12,4.0,4.0,0.0,...
# 1                    1  100.0,88.0,0.78,0.02,0.08,0.13,0.07,16.0,16.0,...
# 2                    1  100.0,88.0,0.78,0.02,0.08,0.13,0.07,16.0,16.0,...
# 3                    1  49.0,43.0,0.775510204082,0.0,0.265306122449,0....
# 4                    1  14.0,14.0,0.785714285714,0.0,0.428571428571,0....
# ...                ...                                                ...
# 571922              -1  83.0,70.0,0.78313253012,0.0,0.10843373494,0.16...
# 571923               1  121.0,105.0,0.719008264463,0.0165289256198,0.0...
# 571924               1  68.0,58.0,0.764705882353,0.0,0.147058823529,0....
# 571925              -1  96.0,79.0,0.770833333333,0.0,0.0729166666667,0...
# 571926               1  140.0,122.0,0.8,0.0,0.114285714286,0.135714285...
#
# [571927 rows x 6 columns]

# %%
df=dataframe
aray2=df[['SOURCE_SUBREDDIT', 'TARGET_SUBREDDIT']] = df[['SOURCE_SUBREDDIT', 'TARGET_SUBREDDIT']].where(df['LINK_SENTIMENT'] !=-1, df[['TARGET_SUBREDDIT', 'SOURCE_SUBREDDIT']].values)
df
# Out:
#          SOURCE_SUBREDDIT     TARGET_SUBREDDIT  POST_ID         TIMESTAMP  \
# 0              rddtgaming             rddtrust  1u4pzzs  12/31/2013 16:39
# 1                 xboxone        battlefield_4  1u4tmfs  12/31/2013 17:59
# 2                     ps4        battlefield_4  1u4tmos  12/31/2013 17:59
# 3       fitnesscirclejerk            leangains  1u50xfs  12/31/2013 19:01
# 4       fitnesscirclejerk          lifeprotips  1u51nps  12/31/2013 21:02
# ...                   ...                  ...      ...               ...
# 571922          seattlewa      seattleshitshow   68iptp   4/27/2017 11:07
# 571923   peoplewhosayheck            spiderman  68iqh6s   4/30/2017 16:36
# 571924               vzla                  wtf  68iqkcs   4/30/2017 15:50
# 571925                nfl        denverbroncos   68iqt8   4/30/2017 16:11
# 571926   shitpoliticssays  politicaldiscussion  68ir4os   4/30/2017 15:14
#
#         LINK_SENTIMENT                                         PROPERTIES
# 0                    1  25.0,23.0,0.76,0.0,0.44,0.12,0.12,4.0,4.0,0.0,...
# 1                    1  100.0,88.0,0.78,0.02,0.08,0.13,0.07,16.0,16.0,...
# 2                    1  100.0,88.0,0.78,0.02,0.08,0.13,0.07,16.0,16.0,...
# 3                    1  49.0,43.0,0.775510204082,0.0,0.265306122449,0....
# 4                    1  14.0,14.0,0.785714285714,0.0,0.428571428571,0....
# ...                ...                                                ...
# 571922              -1  83.0,70.0,0.78313253012,0.0,0.10843373494,0.16...
# 571923               1  121.0,105.0,0.719008264463,0.0165289256198,0.0...
# 571924               1  68.0,58.0,0.764705882353,0.0,0.147058823529,0....
# 571925              -1  96.0,79.0,0.770833333333,0.0,0.0729166666667,0...
# 571926               1  140.0,122.0,0.8,0.0,0.114285714286,0.135714285...
#
# [571927 rows x 6 columns]

# %% [markdown]
# ** Replaces and updates reverse link and source destination. **

# %%
df['LINK_SENTIMENT']=1
df
# Out:
#          SOURCE_SUBREDDIT     TARGET_SUBREDDIT  POST_ID         TIMESTAMP  \
# 0              rddtgaming             rddtrust  1u4pzzs  12/31/2013 16:39
# 1                 xboxone        battlefield_4  1u4tmfs  12/31/2013 17:59
# 2                     ps4        battlefield_4  1u4tmos  12/31/2013 17:59
# 3       fitnesscirclejerk            leangains  1u50xfs  12/31/2013 19:01
# 4       fitnesscirclejerk          lifeprotips  1u51nps  12/31/2013 21:02
# ...                   ...                  ...      ...               ...
# 571922          seattlewa      seattleshitshow   68iptp   4/27/2017 11:07
# 571923   peoplewhosayheck            spiderman  68iqh6s   4/30/2017 16:36
# 571924               vzla                  wtf  68iqkcs   4/30/2017 15:50
# 571925                nfl        denverbroncos   68iqt8   4/30/2017 16:11
# 571926   shitpoliticssays  politicaldiscussion  68ir4os   4/30/2017 15:14
#
#         LINK_SENTIMENT                                         PROPERTIES
# 0                    1  25.0,23.0,0.76,0.0,0.44,0.12,0.12,4.0,4.0,0.0,...
# 1                    1  100.0,88.0,0.78,0.02,0.08,0.13,0.07,16.0,16.0,...
# 2                    1  100.0,88.0,0.78,0.02,0.08,0.13,0.07,16.0,16.0,...
# 3                    1  49.0,43.0,0.775510204082,0.0,0.265306122449,0....
# 4                    1  14.0,14.0,0.785714285714,0.0,0.428571428571,0....
# ...                ...                                                ...
# 571922               1  83.0,70.0,0.78313253012,0.0,0.10843373494,0.16...
# 571923               1  121.0,105.0,0.719008264463,0.0165289256198,0.0...
# 571924               1  68.0,58.0,0.764705882353,0.0,0.147058823529,0....
# 571925               1  96.0,79.0,0.770833333333,0.0,0.0729166666667,0...
# 571926               1  140.0,122.0,0.8,0.0,0.114285714286,0.135714285...
#
# [571927 rows x 6 columns]

# %%
**Dropping Not required Columns**

# %%
df=df.drop(['TIMESTAMP','LINK_SENTIMENT','PROPERTIES'],axis=1)
df
# Out:
#          SOURCE_SUBREDDIT     TARGET_SUBREDDIT  POST_ID
# 0              rddtgaming             rddtrust  1u4pzzs
# 1                 xboxone        battlefield_4  1u4tmfs
# 2                     ps4        battlefield_4  1u4tmos
# 3       fitnesscirclejerk            leangains  1u50xfs
# 4       fitnesscirclejerk          lifeprotips  1u51nps
# ...                   ...                  ...      ...
# 571922          seattlewa      seattleshitshow   68iptp
# 571923   peoplewhosayheck            spiderman  68iqh6s
# 571924               vzla                  wtf  68iqkcs
# 571925                nfl        denverbroncos   68iqt8
# 571926   shitpoliticssays  politicaldiscussion  68ir4os
#
# [571927 rows x 3 columns]

# %%
**Reading limited Entries from Dataframe**

# %%
newDataframe=df.head(500);
array1=newDataframe['SOURCE_SUBREDDIT'].unique()
array1
# Out:
# array(['rddtgaming', 'xboxone', 'ps4', 'fitnesscirclejerk', 'cancer',
#        'jleague', 'bestoftldr', 'quityourbullshit', 'bestof',
#        'anarchychess', 'internet_box', 'ffxiv', 'switcharoo',
#        'bitcoinmining', 'nfl', 'corgi', 'propaganda', 'orlando',
#        'bitcoin', 'electronic_cigarette', 'rba', 'agitation',
#        'magicskyfairy', 'dayz', 'languagelearning', 'bestof2013', 'wkuk',
#        'libsridan', 'gybb', 'circlebroke2', 'technology',
#        'examplesofevil', 'leningrad', 'totallystraight', 'littlespace',
#        'metahub', 'eminem', 'vegan', 'disney', 'eddfaction', 'fulhamfc',
#        'edmprodcirclejerk', 'pocket_universe', 'mindcrack',
#        'foodforthought', 'shitamericanssay', 'allthingsterran',
#        'christianity', 'allthingszerg', 'thewire', 'connectedcareers',
#        'redoric', 'protectandserve', 'greatadvice', 'adviceanimals',
#        'dogecoin', 'floridagators', 'shitstatistssay', 'xcution',
#        'lasnoches', 'metacanada', 'notcirclejerk', 'worldpolitics',
#        'dwarffortress', 'civcirclejerk', 'minecraft', 'science',
#        'defaultgems', 'truechristian', 'eprime', 'politics', 'depthhub',
#        'puahate', 'mlptcg', 'panichistory', 'nerdcubed', 'civcraft',
#        'nautical', 'upvote', 'yachts', 'prolife', 'greenbaypackers',
#        'antonscheller', 'thathappened', 'wwi', '49ers', 'mensrights',
#        'conservative', 'mildlyinteresting', 'titlegore', 'danmag',
#        'progressive', 'trudge', 'pics', 'subredditdrama', 'funny',
#        'solotravel', 'nottheonion', 'stlouisblues', 'investmentclub',
#        'retiredgif', 'television', 'trees', 'plantedtank', 'gmomyths',
#        'wotcirclejerk', 'cinemagraphs', 'cringe', 'citn', 'anarchism',
#        'alpharetta', 'battlefield_4', 'gaming', 'badlinguistics',
#        'feminineboys', 'mapporn', 'filmmakers', 'baseballcirclejerk',
#        'ripplers', 'android', 'libertypositive', 'programmingcirclejerk',
#        'vegetarian', 'cringepics', 'socialism', 'ididnazithatcoming',
#        'badphilosophy', 'programming', 'civcommonwealth', 'conspiratard',
#        'mtgfinancirclejerk', 'shitredditsays', 'denvernuggets',
#        'karmamartyr', 'feminism', 'longisland', 'danzilona', 'itpdot',
#        'enoughlibertarianspam', 'badwomensanatomy', 'bad_religion',
#        'bicycling', 'badhistory', 'vegetarianism', 'swiftmangacomics',
#        'penis', 'polyamory', 'drugscirclejerk', 'canada', 'mgtow',
#        'nerdfighters', 'falconsocialclub', 'adviceof', 'books',
#        'nofapchristians', 'smashbros', 'teenagers', 'thebluepill',
#        'skeptic', 'buildapc', 'shitrconservativesays', 'circlebroke',
#        'cooking', 'lovecraft', 'vancouver', 'bbq', 'seduction',
#        'alliteration', 'drugmemes', 'srsbusiness', 'circlejerkaustralia',
#        'mylittleandysonic1', 'restorethefourth', 'bakchodi',
#        'lewronggeneration', 'news', 'decidingtobebetter', 'animation',
#        'aquariums', 'austria', 'switzerland', 'mlpccg',
#        'shittykickstarters', 'fuckharley', 'acceptancespeech',
#        'philippines', 'spacerebooted', 'watches', 'soccer',
#        'todayilearned', 'videos', 'd_language', 'gooddoge', 'usahockey',
#        'karmaconspiracy', 'electronicmusic', 'beyondthebump', 'breakup',
#        'palsbarainaction', 'conspiracy', 'cryptocurrency', 'bestofrzen',
#        'truestl', 'askreddit', 'montageparodies', 'reformed',
#        'writingprompts', 'murica', 'columbus', 'civcringe', 'osu',
#        'clintonville', 'eagles', 'nsl', 'metalgear', 'apple',
#        'mmatechnique', 'mexico', 'veganfitness', 'audioengineering',
#        'mindcrackcirclejerk', 'cfs', 'aussie_vapers', 'heroscape',
#        'games', 'carcrash', 'exjw', 'worldnews', 'wallstreetbets',
#        'opisafag', 'iama', 'ohio', 'phish', 'intj', 'entrepreneur',
#        'comicbooks', 'firstworldanarchists', 'justiceleague',
#        'androidcirclejerk', 'verypunny', 'shitpost', 'sanantonio',
#        'engineeringstudents', 'imgoingtohellforthis', 'submissivemen',
#        'edmproduction', 'jailbreak', 'ballet', 'theorycraft', 'diabetes',
#        'whatsinthisthing', 'dance', 'menscirclejerk', 'cordcutters',
#        'hiphopcirclejerk', 'anarcho_capitalism', 'trailerparkboys',
#        'lotr', 'bodybuilding', 'e_cigarette', 'shitpoliticssays',
#        'malaysia', 'dogecoindev', 'relevantxkcd', 'progmetal',
#        'jailbreakdevelopers', 'love', 'whataboutsrs', 'weddingplanning',
#        'goldredditsays', 'homestuck', 'editors', 'vietnam',
#        'antiatheismwatch', 'indesign', 'oaklandraiders', 'obamacare_',
#        'worstof', 'mechanicalkeyboards', 'iwantout', 'badeconomics',
#        'waitingforop', 'bayarea', 'keto', 'teenguide', 'bestofmlas1',
#        'warhammer40k', 'mathrock', 'rance', 'wtfdidijustread', 'newlisp',
#        'drama', 'calbarexam', 'buddhism', 'trueotherkin',
#        'examplesofgood', 'explainwithahoedown', 'jacksonville',
#        'grandrapids', 'winterreddit', 'gvsu', 'confession',
#        'cinematography', 'clubesteban', 'slp', 'psminecraft', 'fitness',
#        'buffy', 'botsscrewingup', 'darknetplan', 'majorasmask',
#        'exmuslim', 'funnyreddit', 'hinduism', 'hackerspaces', 'nascar',
#        'autowikibot', 'cats', 'bourbon', 'thegeekgroup', 'indianews',
#        'australia', 'circlejerk', 'harrypotter', 'pokemon',
#        'thingsfightingidiots', 'pettyrevenge', 'turbografx', 'toronto',
#        'unexpected', 'formula1', 'japan', 'twoxchromosomes'], dtype=object)

# %%
import string


class Pair:
    def __init__(self, first, second):
        self.first = first
        self.second = second


infi = 100000000000000000000;


# Class of the node
class Node:

    # Adjacency list that shows the
    # vertexNumber of child vertex
    # and the weight of the edge
    def __init__(self, vertexNumber):
        self.vertexNumber = vertexNumber
        self.children = []

    # Function to add the child for
    # the given node
    def Add_child(self, vNumber, length):
        p = Pair(vNumber, length);
        self.children.append(p);

# %%
def BellmanFord(g, s, path):
  
    dist = [infi for i in range(len(g))]

    visited = [False for i in range(len(g))]

    for i in range(len(g)):
        path[i] = -1
    dist[s] = 0;
    path[s] = -1;
    current = s;


    sett = set()
    path1=[]
    path1.append(current)
    while (True):

        
        visited[current] = True;

        for i in range(len(g[current].children)):
            v = g[current].children[i].first;
            path1.append(v);
            if (visited[v]):
                continue;

            sett.add(v);
            alt = dist[current] + g[current].children[i].second;


            if (alt < dist[v]):
                dist[v] = alt;
                path[v] = current;
          #  print(path1);
        if current in sett:
            sett.remove(current);
        if (len(sett) == 0):
            break;
        minDist = infi;
        index = 0;

        
        for a in sett:
            if (dist[a] < minDist):
                minDist = dist[a];
                index = a;
        current = index;
    return dist;



def printPath(path, i, s,array1):
    if (i != s):

        if (path[i] == -1):
            print("Path not found!!");
            return;
        printPath(path, path[i], s,array1);
        print(str(array1[path[i]])+'-->',end=" ");

# %%
v = []

# %%
for j in array1:
    z=int(np.where(array1==j)[0][0])
    a = Node(z);
    v.append(a);
    arraycheck=newDataframe[newDataframe['SOURCE_SUBREDDIT']==j]['TARGET_SUBREDDIT']
    for i in arraycheck:
        arraytemp=np.array([i])
        if(np.where(array1==i)[0].size==0):
            array1=np.append(array1,i)
        loc = int(np.where(array1==i)[0][0])
        v[z].Add_child(loc,1)

# %%
array1[200]
# Out:
# 'cryptocurrency'

# %%
loc = np.where(array1=='starcraft')[0]
loc[0]
# Out:
# 395

# %%
len(v)
# Out:
# 876

# %%
def dijkstraDist(g, s, path):
    # Stores distance of each
    # vertex from source vertex
    dist = [infi for i in range(len(g))]

    # bool array that shows
    # whether the vertex 'i'
    # is visited or not
    visited = [False for i in range(len(g))]

    for i in range(len(g)):
        path[i] = -1
    dist[s] = 0;
    path[s] = -1;
    current = s;

    # Set of vertices that has
    # a parent (one or more)
    # marked as visited
    sett = set()
    path1=[]
    path1.append(current)
    while (True):

        # Mark current as visited
        visited[current] = True;

        for i in range(len(g[current].children)):
            v = g[current].children[i].first;
            path1.append(v);
            if (visited[v]):
                continue;

            # Inserting into the
            # visited vertex
            sett.add(v);
            distTemp=g[current].children[i].second;
            if(distTemp>=0):
                alt = dist[current] + g[current].children[i].second;
            else:
                continue;



            # Condition to check the distance
            # is correct and update it
            # if it is minimum from the previous
            # computed distance
            if (alt < dist[v]):
                dist[v] = alt;
                path[v] = current;
          #  print(path1);
        if current in sett:
            sett.remove(current);
        if (len(sett) == 0):
            break;

        # The new current
        minDist = infi;
        index = 0;

        # Loop to update the distance
        # of the vertices of the graph
        for a in sett:
            if (dist[a] < minDist):
                minDist = dist[a];
                index = a;
        current = index;
    return dist;

# %%
#Dijkstra!

# %%
n = array1.size;
s = 8;

path = [0 for i in range(len(v))];
# print(path);
dist = dijkstraDist(v, s, path);

# print(path);
printPath(path, 60,s,array1);
print(str(array1[60]),end=" ")
print(" ")

    # Loop to print the distance of
    # every node from source vertex
for i in range(len(dist)):
    if (dist[i] == infi):
       #print("{0} and {1} are not " +"connected".format(i, s))
        continue;
    print("Distance of {}th vertex from source vertex {} is: {}".format(i, s, dist[i]));
# Out:
# bestof--> shitstatistssay--> bitcoin--> bestof2013--> metacanada
# Distance of 6th vertex from source vertex 8 is: 4
# Distance of 7th vertex from source vertex 8 is: 4
# Distance of 8th vertex from source vertex 8 is: 0
# Distance of 18th vertex from source vertex 8 is: 2
# Distance of 21th vertex from source vertex 8 is: 3
# Distance of 25th vertex from source vertex 8 is: 3
# Distance of 29th vertex from source vertex 8 is: 5
# Distance of 45th vertex from source vertex 8 is: 3
# Distance of 54th vertex from source vertex 8 is: 3
# Distance of 57th vertex from source vertex 8 is: 1
# Distance of 60th vertex from source vertex 8 is: 4
# Distance of 62th vertex from source vertex 8 is: 4
# Distance of 67th vertex from source vertex 8 is: 2
# Distance of 76th vertex from source vertex 8 is: 3
# Distance of 83th vertex from source vertex 8 is: 5
# Distance of 93th vertex from source vertex 8 is: 4
# Distance of 94th vertex from source vertex 8 is: 2
# Distance of 95th vertex from source vertex 8 is: 3
# Distance of 97th vertex from source vertex 8 is: 2
# Distance of 102th vertex from source vertex 8 is: 1
# Distance of 112th vertex from source vertex 8 is: 3
# Distance of 115th vertex from source vertex 8 is: 3
# Distance of 123th vertex from source vertex 8 is: 2
# Distance of 131th vertex from source vertex 8 is: 1
# Distance of 138th vertex from source vertex 8 is: 3
# Distance of 142th vertex from source vertex 8 is: 3
# Distance of 156th vertex from source vertex 8 is: 3
# Distance of 157th vertex from source vertex 8 is: 3
# Distance of 159th vertex from source vertex 8 is: 3
# Distance of 166th vertex from source vertex 8 is: 6
# Distance of 175th vertex from source vertex 8 is: 2
# Distance of 189th vertex from source vertex 8 is: 1
# Distance of 190th vertex from source vertex 8 is: 4
# Distance of 195th vertex from source vertex 8 is: 4
# Distance of 203th vertex from source vertex 8 is: 2
# Distance of 207th vertex from source vertex 8 is: 3
# Distance of 224th vertex from source vertex 8 is: 2
# Distance of 227th vertex from source vertex 8 is: 3
# Distance of 230th vertex from source vertex 8 is: 3
# Distance of 260th vertex from source vertex 8 is: 4
# Distance of 301th vertex from source vertex 8 is: 1
# Distance of 321th vertex from source vertex 8 is: 4
# Distance of 338th vertex from source vertex 8 is: 3
# Distance of 341th vertex from source vertex 8 is: 5
# Distance of 342th vertex from source vertex 8 is: 1
# Distance of 343th vertex from source vertex 8 is: 1
# Distance of 344th vertex from source vertex 8 is: 1
# Distance of 345th vertex from source vertex 8 is: 1
# Distance of 346th vertex from source vertex 8 is: 1
# Distance of 347th vertex from source vertex 8 is: 1
# Distance of 348th vertex from source vertex 8 is: 1
# Distance of 349th vertex from source vertex 8 is: 1
# Distance of 350th vertex from source vertex 8 is: 1
# Distance of 351th vertex from source vertex 8 is: 1
# Distance of 352th vertex from source vertex 8 is: 1
# Distance of 353th vertex from source vertex 8 is: 1
# Distance of 354th vertex from source vertex 8 is: 1
# Distance of 355th vertex from source vertex 8 is: 1
# Distance of 356th vertex from source vertex 8 is: 1
# Distance of 357th vertex from source vertex 8 is: 1
# Distance of 358th vertex from source vertex 8 is: 1
# Distance of 364th vertex from source vertex 8 is: 3
# Distance of 367th vertex from source vertex 8 is: 4
# Distance of 372th vertex from source vertex 8 is: 4
# Distance of 373th vertex from source vertex 8 is: 4
# Distance of 374th vertex from source vertex 8 is: 4
# Distance of 375th vertex from source vertex 8 is: 4
# Distance of 376th vertex from source vertex 8 is: 4
# Distance of 377th vertex from source vertex 8 is: 4
# Distance of 378th vertex from source vertex 8 is: 4
# Distance of 379th vertex from source vertex 8 is: 4
# Distance of 380th vertex from source vertex 8 is: 4
# Distance of 381th vertex from source vertex 8 is: 4
# Distance of 382th vertex from source vertex 8 is: 4
# Distance of 383th vertex from source vertex 8 is: 4
# Distance of 384th vertex from source vertex 8 is: 4
# Distance of 400th vertex from source vertex 8 is: 3
# Distance of 404th vertex from source vertex 8 is: 2
# Distance of 405th vertex from source vertex 8 is: 2
# Distance of 406th vertex from source vertex 8 is: 2
# Distance of 408th vertex from source vertex 8 is: 5
# Distance of 410th vertex from source vertex 8 is: 5
# Distance of 411th vertex from source vertex 8 is: 4
# Distance of 419th vertex from source vertex 8 is: 4
# Distance of 423th vertex from source vertex 8 is: 4
# Distance of 430th vertex from source vertex 8 is: 3
# Distance of 431th vertex from source vertex 8 is: 3
# Distance of 432th vertex from source vertex 8 is: 3
# Distance of 433th vertex from source vertex 8 is: 3
# Distance of 434th vertex from source vertex 8 is: 3
# Distance of 436th vertex from source vertex 8 is: 3
# Distance of 439th vertex from source vertex 8 is: 2
# Distance of 440th vertex from source vertex 8 is: 2
# Distance of 448th vertex from source vertex 8 is: 4
# Distance of 449th vertex from source vertex 8 is: 4
# Distance of 462th vertex from source vertex 8 is: 2
# Distance of 463th vertex from source vertex 8 is: 2
# Distance of 464th vertex from source vertex 8 is: 2
# Distance of 467th vertex from source vertex 8 is: 4
# Distance of 471th vertex from source vertex 8 is: 4
# Distance of 472th vertex from source vertex 8 is: 4
# Distance of 473th vertex from source vertex 8 is: 4
# Distance of 474th vertex from source vertex 8 is: 4
# Distance of 478th vertex from source vertex 8 is: 3
# Distance of 488th vertex from source vertex 8 is: 2
# Distance of 489th vertex from source vertex 8 is: 5
# Distance of 490th vertex from source vertex 8 is: 5
# Distance of 491th vertex from source vertex 8 is: 5
# Distance of 494th vertex from source vertex 8 is: 3
# Distance of 497th vertex from source vertex 8 is: 4

# %%
# Bellman Ford

# %%
n = array1.size;
s = 8;

path = [0 for i in range(len(v))];
dist = BellmanFord(v, s, path);

printPath(path, 29,s,array1);
print(str(array1[29]),end=" ")
print(" ")

for i in range(len(dist)):
    if (dist[i] == infi):
       #print("{0} and {1} are not " +"connected".format(i, s))
        continue;
    print("Distance of {} vertex from source vertex {} is: {}".format(i, s, dist[i]));
# Out:
# bestof--> trees--> subredditdrama--> mapporn--> australia--> circlebroke2
# Distance of 6 vertex from source vertex 8 is: 4
# Distance of 7 vertex from source vertex 8 is: 4
# Distance of 8 vertex from source vertex 8 is: 0
# Distance of 18 vertex from source vertex 8 is: 2
# Distance of 21 vertex from source vertex 8 is: 3
# Distance of 25 vertex from source vertex 8 is: 3
# Distance of 29 vertex from source vertex 8 is: 5
# Distance of 45 vertex from source vertex 8 is: 3
# Distance of 54 vertex from source vertex 8 is: 3
# Distance of 57 vertex from source vertex 8 is: 1
# Distance of 60 vertex from source vertex 8 is: 4
# Distance of 62 vertex from source vertex 8 is: 4
# Distance of 67 vertex from source vertex 8 is: 2
# Distance of 76 vertex from source vertex 8 is: 3
# Distance of 83 vertex from source vertex 8 is: 5
# Distance of 93 vertex from source vertex 8 is: 4
# Distance of 94 vertex from source vertex 8 is: 2
# Distance of 95 vertex from source vertex 8 is: 3
# Distance of 97 vertex from source vertex 8 is: 2
# Distance of 102 vertex from source vertex 8 is: 1
# Distance of 112 vertex from source vertex 8 is: 3
# Distance of 115 vertex from source vertex 8 is: 3
# Distance of 123 vertex from source vertex 8 is: 2
# Distance of 131 vertex from source vertex 8 is: 1
# Distance of 138 vertex from source vertex 8 is: 3
# Distance of 142 vertex from source vertex 8 is: 3
# Distance of 156 vertex from source vertex 8 is: 3
# Distance of 157 vertex from source vertex 8 is: 3
# Distance of 159 vertex from source vertex 8 is: 3
# Distance of 166 vertex from source vertex 8 is: 6
# Distance of 175 vertex from source vertex 8 is: 2
# Distance of 189 vertex from source vertex 8 is: 1
# Distance of 190 vertex from source vertex 8 is: 4
# Distance of 195 vertex from source vertex 8 is: 4
# Distance of 203 vertex from source vertex 8 is: 2
# Distance of 207 vertex from source vertex 8 is: 3
# Distance of 224 vertex from source vertex 8 is: 2
# Distance of 227 vertex from source vertex 8 is: 3
# Distance of 230 vertex from source vertex 8 is: 3
# Distance of 260 vertex from source vertex 8 is: 4
# Distance of 301 vertex from source vertex 8 is: 1
# Distance of 321 vertex from source vertex 8 is: 4
# Distance of 338 vertex from source vertex 8 is: 3
# Distance of 341 vertex from source vertex 8 is: 5
# Distance of 342 vertex from source vertex 8 is: 1
# Distance of 343 vertex from source vertex 8 is: 1
# Distance of 344 vertex from source vertex 8 is: 1
# Distance of 345 vertex from source vertex 8 is: 1
# Distance of 346 vertex from source vertex 8 is: 1
# Distance of 347 vertex from source vertex 8 is: 1
# Distance of 348 vertex from source vertex 8 is: 1
# Distance of 349 vertex from source vertex 8 is: 1
# Distance of 350 vertex from source vertex 8 is: 1
# Distance of 351 vertex from source vertex 8 is: 1
# Distance of 352 vertex from source vertex 8 is: 1
# Distance of 353 vertex from source vertex 8 is: 1
# Distance of 354 vertex from source vertex 8 is: 1
# Distance of 355 vertex from source vertex 8 is: 1
# Distance of 356 vertex from source vertex 8 is: 1
# Distance of 357 vertex from source vertex 8 is: 1
# Distance of 358 vertex from source vertex 8 is: 1
# Distance of 364 vertex from source vertex 8 is: 3
# Distance of 367 vertex from source vertex 8 is: 4
# Distance of 372 vertex from source vertex 8 is: 4
# Distance of 373 vertex from source vertex 8 is: 4
# Distance of 374 vertex from source vertex 8 is: 4
# Distance of 375 vertex from source vertex 8 is: 4
# Distance of 376 vertex from source vertex 8 is: 4
# Distance of 377 vertex from source vertex 8 is: 4
# Distance of 378 vertex from source vertex 8 is: 4
# Distance of 379 vertex from source vertex 8 is: 4
# Distance of 380 vertex from source vertex 8 is: 4
# Distance of 381 vertex from source vertex 8 is: 4
# Distance of 382 vertex from source vertex 8 is: 4
# Distance of 383 vertex from source vertex 8 is: 4
# Distance of 384 vertex from source vertex 8 is: 4
# Distance of 400 vertex from source vertex 8 is: 3
# Distance of 404 vertex from source vertex 8 is: 2
# Distance of 405 vertex from source vertex 8 is: 2
# Distance of 406 vertex from source vertex 8 is: 2
# Distance of 408 vertex from source vertex 8 is: 5
# Distance of 410 vertex from source vertex 8 is: 5
# Distance of 411 vertex from source vertex 8 is: 4
# Distance of 419 vertex from source vertex 8 is: 4
# Distance of 423 vertex from source vertex 8 is: 4
# Distance of 430 vertex from source vertex 8 is: 3
# Distance of 431 vertex from source vertex 8 is: 3
# Distance of 432 vertex from source vertex 8 is: 3
# Distance of 433 vertex from source vertex 8 is: 3
# Distance of 434 vertex from source vertex 8 is: 3
# Distance of 436 vertex from source vertex 8 is: 3
# Distance of 439 vertex from source vertex 8 is: 2
# Distance of 440 vertex from source vertex 8 is: 2
# Distance of 448 vertex from source vertex 8 is: 4
# Distance of 449 vertex from source vertex 8 is: 4
# Distance of 462 vertex from source vertex 8 is: 2
# Distance of 463 vertex from source vertex 8 is: 2
# Distance of 464 vertex from source vertex 8 is: 2
# Distance of 467 vertex from source vertex 8 is: 4
# Distance of 471 vertex from source vertex 8 is: 4
# Distance of 472 vertex from source vertex 8 is: 4
# Distance of 473 vertex from source vertex 8 is: 4
# Distance of 474 vertex from source vertex 8 is: 4
# Distance of 478 vertex from source vertex 8 is: 3
# Distance of 488 vertex from source vertex 8 is: 2
# Distance of 489 vertex from source vertex 8 is: 5
# Distance of 490 vertex from source vertex 8 is: 5
# Distance of 491 vertex from source vertex 8 is: 5
# Distance of 494 vertex from source vertex 8 is: 3
# Distance of 497 vertex from source vertex 8 is: 4

# %%
#Diameter Of Graph!

# %%
maxd=-1;
for j in array1:
    s=z=int(np.where(array1==j)[0][0])
    path = [0 for i in range(len(v))];
# print(path);
    dist = dijkstraDist(v, s, path);
    for i in dist:
        if(i!=100000000000000000000):
            if(i>maxd):
                maxd=i

print("Diameter of graph: " + str(maxd));
# Out:
# Diameter of graph: 15
